# %%
import numpy as np

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

os.chdir("C:/Users/Pranshul/Desktop/machine-learning-ex1/ex1")
data = pd.read_csv("ex1data1.txt")

# %%
data
# Out:
#           X         Y
# 0    6.1101  17.59200
# 1    5.5277   9.13020
# 2    8.5186  13.66200
# 3    7.0032  11.85400
# 4    5.8598   6.82330
# ..      ...       ...
# 92   5.8707   7.20290
# 93   5.3054   1.98690
# 94   8.2934   0.14454
# 95  13.3940   9.05510
# 96   5.4369   0.61705
#
# [97 rows x 2 columns]

# %%
X = np.array(data.X)
Y = np.array(data.Y)

# %%
plt.plot(X)
plt.plot(Y)
plt.show()

# %%
def CostFunction (theta,X,Y):
    m = X.shape[0];
    J = 0;
    for n in range(0,m):
        h = theta[0] + theta[1]*X[n] ;
        J = J + pow((h - Y[n]),2);
    J = J/(2*m);
    return J;

# %%
iterations = 20000;
alpha = 0.01;
theta = np.array([0.,0.]);
for s in range(0,iterations):
    m = X.shape[0];
    a = 0;
    for n in range(0,m):
        h = theta[0] + theta[1]*X[n] ;
        a = a + (h - Y[n]);
    a = a/(m);
    q = theta.shape[0];
    for n in range(0,q):
        theta[n] = theta[n] - alpha*a;
theta
# Out:
# array([0.63747408, 0.63747408])

# %%
plt.scatter(X,Y)
plt.plot(X,theta[0] + theta[1]*X)
